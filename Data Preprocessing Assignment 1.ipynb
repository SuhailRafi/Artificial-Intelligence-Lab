# %% [markdown]
# ## CSE 422 Introduction to Data Preprocessing
# ---

# %% [markdown]
# ### What are the advantages of preprocessing the data before applying on machine learning algorithm?
#
# "The biggest advantage of pre-processing in ML is to improve **generalizablity** of your model. Data for any ML application is collected through some ‘sensors’. These sensors can be physical devices, instruments, software programs such as web crawlers, manual surveys, etc. Due to hardware malfunctions, software glitches, instrument failures, amd human errors, noise and erroneous information may creep in that can severely affect the performance of your model. Apart from **noise**, there are several **redundant information** that needs to be removed. For e.g. while predicting whether it rains tomorrow or not, age of the person is irrelevant. In terms of text processing, there are several stop words that may be redundant for the analysis. Lastly, there may be several **outliers** present in your data, due to the way data is collected that may need to be removed to improve the performance of the classifiers."
#
#                                             -Shehroz Khan, ML Researcher, Postdoc @U of Toronto

# %% [markdown]
# Some Data Preprocessing Techniques:
#
# * Deleting duplicate and null values
# * Imputation for missing values
# * Handling Categorical Features
# * Feature Normalization/Scaling
# * Feature Engineering
# * Feature Selection

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# #Removing Null values / Handling Missing data

# %%
df = pd.read_csv('/kaggle/input/glass-source-classification-datasetcsv/Glass Source Classification Dataset.csv')
df.sample(25)
# Out:
#      Unnamed: 0       RI     Na    Mg    Al     Si     K     Ca  \
# 186         186  1.51838  14.32  3.26  2.22  71.25  1.46   5.79
# 136         136  1.51806  13.00  3.80  1.08  73.07  0.56   8.38
# 140         140  1.51690  13.33  3.54  1.61  72.54  0.68   8.11
# 34           34  1.51783  12.69  3.54  1.34  72.95  0.57   8.75
# 169         169  1.51994  13.27  0.00  1.76  73.03  0.47  11.32
# 58           58  1.51754  13.48  3.74  1.17  72.99  0.59   8.03
# 200         200  1.51508  15.15  0.00  2.25  73.50  0.00   8.34
# 177         177  1.51937  13.79  2.41  1.19  72.76  0.00   9.77
# 49           49  1.51898  13.58  3.35  1.23  72.08  0.59   8.91
# 137         137  1.51711  12.89  3.62  1.57  72.96  0.61   8.11
# 78           78  1.51613  13.92  3.52  1.25  72.88  0.37   7.94
# 37           37  1.51797  12.74  3.48  1.35  72.96  0.64   8.68
# 30           30  1.51768  12.65  3.56  1.30  73.08  0.61   8.69
# 175         175  1.52119  12.97  0.33  1.51  73.39  0.13  11.27
# 38           38  1.52213  14.21  3.82  0.47  71.77  0.11   9.57
# 33           33  1.51753  12.57  3.47  1.38  73.39  0.60   8.55
# 126         126  1.51667  12.94  3.61  1.26  72.75  0.56   8.60
# 118         118  1.51673  13.30  3.64  1.53  72.53  0.65   8.03
# 97           97  1.51743  12.20  3.25  1.16  73.55  0.62   8.90
# 76           76  1.51645  13.44  3.61  1.54  72.39  0.66   8.03
# 101         101  1.51730  12.35  2.72  1.63  72.87  0.70   9.23
# 144         144  1.51660  12.99  3.18  1.23  72.97  0.58    NaN
# 147         147  1.51610  13.33  3.53  1.34  72.67  0.56   8.33
# 63           63  1.52227  14.17  3.81  0.78  71.35  0.00   9.69
# 122         122  1.51687  13.23  3.54  1.48  72.84  0.56   8.10
#
#                  Ba              Fe                   Type
# 186          exists  Does not exist         headlamp glass
# 136  Does not exist          exists  building_window glass
# 140  Does not exist  Does not exist  building_window glass
# 34   Does not exist  Does not exist  building_window glass
# 169  Does not exist  Does not exist        container glass
# 58   Does not exist  Does not exist  building_window glass
# 200          exists  Does not exist         headlamp glass
# 177  Does not exist  Does not exist        tableware glass
# 49   Does not exist  Does not exist  building_window glass
# 137  Does not exist  Does not exist  building_window glass
# 78   Does not exist          exists  building_window glass
# 37   Does not exist  Does not exist  building_window glass
# 30   Does not exist          exists  building_window glass
# 175  Does not exist          exists        container glass
# 38   Does not exist  Does not exist  building_window glass
# 33   Does not exist          exists  building_window glass
# 126  Does not exist  Does not exist  building_window glass
# 118  Does not exist          exists  building_window glass
# 97   Does not exist          exists  building_window glass
# 76   Does not exist  Does not exist  building_window glass
# 101  Does not exist  Does not exist  building_window glass
# 144  Does not exist          exists  building_window glass
# 147  Does not exist  Does not exist   vehicle_window glass
# 63   Does not exist  Does not exist  building_window glass
# 122  Does not exist  Does not exist  building_window glass

# %%
df.shape
# Out:
# (214, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# RI            0
# Na            0
# Mg            0
# Al            0
# Si            0
# K             0
# Ca            6
# Ba            0
# Fe            0
# Type          0
# dtype: int64

# %% [markdown]
# dropping columns

# %%
df = df.drop(['Unnamed: 0'], axis = 1)
df.shape
# Out:
# (214, 10)

# %%
df.sample(10)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca              Ba  \
# 69   1.52300  13.31  3.58  0.82  71.99  0.12  10.17  Does not exist
# 141  1.51851  13.20  3.63  1.07  72.83  0.57   8.41          exists
# 67   1.52152  13.05  3.65  0.87  72.32  0.19   9.85  Does not exist
# 136  1.51806  13.00  3.80  1.08  73.07  0.56   8.38  Does not exist
# 211  1.52065  14.36  0.00  2.02  73.42  0.00   8.44          exists
# 71   1.51848  13.64  3.87  1.27  71.96  0.54   8.32  Does not exist
# 122  1.51687  13.23  3.54  1.48  72.84  0.56   8.10  Does not exist
# 199  1.51609  15.01  0.00  2.51  73.05  0.05   8.83          exists
# 48   1.52223  13.21  3.77  0.79  71.99  0.13  10.02  Does not exist
# 29   1.51784  13.08  3.49  1.28  72.86  0.60   8.49  Does not exist
#
#                  Fe                   Type
# 69           exists  building_window glass
# 141          exists  building_window glass
# 67           exists  building_window glass
# 136          exists  building_window glass
# 211  Does not exist         headlamp glass
# 71           exists  building_window glass
# 122  Does not exist  building_window glass
# 199  Does not exist         headlamp glass
# 48   Does not exist  building_window glass
# 29   Does not exist  building_window glass

# %% [markdown]
# ### Imputing missing Values

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(missing_values=np.nan, strategy='median')

impute.fit(df[['Ca']])

df['Ca'] = impute.transform(df[['Ca']])

# %%
df.sample(10)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca              Ba  \
# 64   1.52172  13.48  3.74  0.90  72.01  0.18   9.61  Does not exist
# 16   1.51784  12.68  3.67  1.16  73.11  0.61   8.70  Does not exist
# 86   1.51569  13.24  3.49  1.47  73.25  0.38   8.03  Does not exist
# 60   1.51905  13.60  3.62  1.11  72.64  0.14   8.76  Does not exist
# 83   1.51594  13.09  3.52  1.55  72.87  0.68   8.05  Does not exist
# 28   1.51768  12.56  3.52  1.43  73.15  0.57   8.54  Does not exist
# 14   1.51763  12.61  3.59  1.31  73.29  0.58   8.50  Does not exist
# 112  1.52777  12.64  0.00  0.67  72.02  0.06  14.40  Does not exist
# 143  1.51709  13.00  3.47  1.79  72.72  0.66   8.18  Does not exist
# 211  1.52065  14.36  0.00  2.02  73.42  0.00   8.44          exists
#
#                  Fe                   Type
# 64           exists  building_window glass
# 16   Does not exist  building_window glass
# 86   Does not exist  building_window glass
# 60   Does not exist  building_window glass
# 83           exists  building_window glass
# 28   Does not exist  building_window glass
# 14   Does not exist  building_window glass
# 112  Does not exist  building_window glass
# 143  Does not exist  building_window glass
# 211  Does not exist         headlamp glass

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Encoding categorical variables - binary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    object
#  8   Fe      214 non-null    object
#  9   Type    214 non-null    object
# dtypes: float64(7), object(3)
# memory usage: 16.8+ KB

# %%
df['Ba'].unique()
# Out:
# array(['Does not exist', 'exists'], dtype=object)

# %%
df['Fe'].unique()
# Out:
# array(['Does not exist', 'exists'], dtype=object)

# %%
df['Type'].unique()
# Out:
# array(['building_window glass', 'vehicle_window glass', 'container glass',
#        'tableware glass', 'headlamp glass'], dtype=object)

# %% [markdown]
# ### Encoding categorical variables - one-hot encoding

# %%
df['Ba'] = df['Ba'].map({'exists':1,'Does not exist':0}) 
df.sample(30)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca  Ba              Fe  \
# 117  1.51708  13.72  3.68  1.81  72.06  0.64   7.88   0  Does not exist
# 57   1.51824  12.87  3.48  1.29  72.95  0.60   8.60   0  Does not exist
# 137  1.51711  12.89  3.62  1.57  72.96  0.61   8.11   0  Does not exist
# 108  1.52222  14.43  0.00  1.00  72.67  0.10  11.52   0          exists
# 63   1.52227  14.17  3.81  0.78  71.35  0.00   9.69   0  Does not exist
# 81   1.51593  13.25  3.45  1.43  73.17  0.61   7.86   0  Does not exist
# 142  1.51662  12.85  3.51  1.44  73.01  0.68   8.23   1          exists
# 190  1.51613  13.88  1.78  1.79  73.10  0.00   8.67   1  Does not exist
# 120  1.51844  13.25  3.76  1.32  72.40  0.58   8.42   0  Does not exist
# 156  1.51655  13.41  3.39  1.28  72.64  0.52   8.65   0  Does not exist
# 98   1.51689  12.67  2.88  1.71  73.21  0.73   8.54   0  Does not exist
# 152  1.51779  13.64  3.65  0.65  73.00  0.06   8.93   0  Does not exist
# 95   1.51860  13.36  3.43  1.43  72.26  0.51   8.60   0  Does not exist
# 185  1.51131  13.69  3.20  1.81  72.81  1.76   5.43   1  Does not exist
# 17   1.52196  14.36  3.85  0.89  71.36  0.15   9.15   0  Does not exist
# 103  1.52725  13.80  3.15  0.66  70.57  0.08  11.64   0  Does not exist
# 14   1.51763  12.61  3.59  1.31  73.29  0.58   8.50   0  Does not exist
# 82   1.51646  13.41  3.55  1.25  72.81  0.68   8.10   0  Does not exist
# 157  1.52121  14.03  3.76  0.58  71.79  0.11   9.65   0  Does not exist
# 11   1.51763  12.80  3.66  1.27  73.01  0.60   8.56   0  Does not exist
# 2    1.51618  13.53  3.55  1.54  72.99  0.39   7.78   0  Does not exist
# 77   1.51627  13.00  3.58  1.54  72.83  0.61   8.04   0  Does not exist
# 206  1.51645  14.94  0.00  1.87  73.11  0.00   8.67   1  Does not exist
# 161  1.51934  13.64  3.54  0.75  72.65  0.16   8.89   1          exists
# 43   1.52210  13.73  3.84  0.72  71.76  0.17   9.74   0  Does not exist
# 143  1.51709  13.00  3.47  1.79  72.72  0.66   8.18   0  Does not exist
# 136  1.51806  13.00  3.80  1.08  73.07  0.56   8.38   0          exists
# 181  1.51888  14.99  0.78  1.74  72.50  0.00   9.95   0  Does not exist
# 100  1.51655  12.75  2.85  1.44  73.27  0.57   8.79   1          exists
# 140  1.51690  13.33  3.54  1.61  72.54  0.68   8.11   0  Does not exist
#
#                       Type
# 117  building_window glass
# 57   building_window glass
# 137  building_window glass
# 108  building_window glass
# 63   building_window glass
# 81   building_window glass
# 142  building_window glass
# 190         headlamp glass
# 120  building_window glass
# 156   vehicle_window glass
# 98   building_window glass
# 152   vehicle_window glass
# 95   building_window glass
# 185         headlamp glass
# 17   building_window glass
# 103  building_window glass
# 14   building_window glass
# 82   building_window glass
# 157   vehicle_window glass
# 11   building_window glass
# 2    building_window glass
# 77   building_window glass
# 206         headlamp glass
# 161   vehicle_window glass
# 43   building_window glass
# 143  building_window glass
# 136  building_window glass
# 181        tableware glass
# 100  building_window glass
# 140  building_window glass

# %%
df['Fe'] = df['Fe'].map({'exists':1,'Does not exist':0}) 
df.sample(30)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca  Ba  Fe  \
# 37   1.51797  12.74  3.48  1.35  72.96  0.64   8.68   0   0
# 16   1.51784  12.68  3.67  1.16  73.11  0.61   8.70   0   0
# 6    1.51743  13.30  3.60  1.14  73.09  0.58   8.17   0   0
# 143  1.51709  13.00  3.47  1.79  72.72  0.66   8.18   0   0
# 11   1.51763  12.80  3.66  1.27  73.01  0.60   8.56   0   0
# 50   1.52320  13.72  3.72  0.51  71.75  0.09  10.06   0   1
# 182  1.51916  14.15  0.00  2.09  72.74  0.00  10.88   0   0
# 0    1.52101  13.64  4.49  1.10  71.78  0.06   8.60   0   0
# 85   1.51625  13.36  3.58  1.49  72.72  0.45   8.21   0   0
# 29   1.51784  13.08  3.49  1.28  72.86  0.60   8.49   0   0
# 83   1.51594  13.09  3.52  1.55  72.87  0.68   8.05   0   1
# 176  1.51905  14.00  2.39  1.56  72.37  0.00   9.57   0   0
# 153  1.51610  13.42  3.40  1.22  72.69  0.59   8.32   0   0
# 172  1.51321  13.00  0.00  3.02  70.70  6.21   6.93   0   0
# 84   1.51409  14.25  3.09  2.08  72.28  1.10   7.08   0   0
# 145  1.51839  12.85  3.67  1.24  72.57  0.62   8.68   0   1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39   7.78   0   0
# 47   1.52667  13.99  3.70  0.71  71.57  0.02   9.82   0   1
# 161  1.51934  13.64  3.54  0.75  72.65  0.16   8.89   1   1
# 93   1.51590  13.24  3.34  1.47  73.10  0.39   8.22   0   0
# 82   1.51646  13.41  3.55  1.25  72.81  0.68   8.10   0   0
# 195  1.51545  14.14  0.00  2.68  73.39  0.08   9.07   1   1
# 130  1.52177  13.75  1.01  1.36  72.19  0.33  11.14   0   0
# 159  1.51796  13.50  3.36  1.63  71.94  0.57   8.81   0   1
# 67   1.52152  13.05  3.65  0.87  72.32  0.19   9.85   0   1
# 63   1.52227  14.17  3.81  0.78  71.35  0.00   9.69   0   0
# 165  1.52171  11.56  1.88  1.56  72.86  0.47  11.41   0   0
# 95   1.51860  13.36  3.43  1.43  72.26  0.51   8.60   0   0
# 17   1.52196  14.36  3.85  0.89  71.36  0.15   9.15   0   0
# 34   1.51783  12.69  3.54  1.34  72.95  0.57   8.75   0   0
#
#                       Type
# 37   building_window glass
# 16   building_window glass
# 6    building_window glass
# 143  building_window glass
# 11   building_window glass
# 50   building_window glass
# 182        tableware glass
# 0    building_window glass
# 85   building_window glass
# 29   building_window glass
# 83   building_window glass
# 176        tableware glass
# 153   vehicle_window glass
# 172        container glass
# 84   building_window glass
# 145  building_window glass
# 2    building_window glass
# 47   building_window glass
# 161   vehicle_window glass
# 93   building_window glass
# 82   building_window glass
# 195         headlamp glass
# 130  building_window glass
# 159   vehicle_window glass
# 67   building_window glass
# 63   building_window glass
# 165        container glass
# 95   building_window glass
# 17   building_window glass
# 34   building_window glass

# %% [markdown]
# We may also encode/map a certain class to a specific code (e.g 0/1/2) by using the `map()` function.

# %%
df['Type'] = df['Type'].map({'building_window glass':0,'vehicle_window glass':1,'container glass':2, 'tableware glass': 3, 'headlamp glass': 4}) 
df.sample(30)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca  Ba  Fe  Type
# 56   1.51215  12.99  3.47  1.12  72.98  0.62   8.35   0   1     0
# 149  1.51643  12.16  3.52  1.35  72.89  0.57   8.53   0   0     1
# 63   1.52227  14.17  3.81  0.78  71.35  0.00   9.69   0   0     0
# 145  1.51839  12.85  3.67  1.24  72.57  0.62   8.68   0   1     0
# 158  1.51776  13.53  3.41  1.52  72.04  0.58   8.79   0   0     1
# 25   1.51764  12.98  3.54  1.21  73.00  0.65   8.53   0   0     0
# 29   1.51784  13.08  3.49  1.28  72.86  0.60   8.49   0   0     0
# 137  1.51711  12.89  3.62  1.57  72.96  0.61   8.11   0   0     0
# 116  1.51829  13.24  3.90  1.41  72.33  0.55   8.31   0   1     0
# 204  1.51617  14.95  0.00  2.27  73.30  0.00   8.71   1   0     4
# 69   1.52300  13.31  3.58  0.82  71.99  0.12  10.17   0   1     0
# 200  1.51508  15.15  0.00  2.25  73.50  0.00   8.34   1   0     4
# 171  1.51316  13.02  0.00  3.04  70.48  6.21   6.96   0   0     2
# 5    1.51596  12.79  3.61  1.62  72.97  0.64   8.07   0   1     0
# 27   1.51721  12.87  3.48  1.33  73.04  0.56   8.43   0   0     0
# 20   1.51750  12.82  3.55  1.49  72.75  0.54   8.52   0   1     0
# 161  1.51934  13.64  3.54  0.75  72.65  0.16   8.89   1   1     1
# 213  1.51711  14.23  0.00  2.08  73.36  0.00   8.62   1   0     4
# 100  1.51655  12.75  2.85  1.44  73.27  0.57   8.79   1   1     0
# 80   1.51592  12.86  3.52  2.12  72.66  0.69   7.97   0   0     0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55   8.07   0   0     0
# 35   1.51567  13.29  3.45  1.21  72.74  0.56   8.57   0   0     0
# 148  1.51670  13.24  3.57  1.38  72.70  0.56   8.44   0   1     1
# 183  1.51969  14.56  0.00  0.56  73.48  0.00  11.22   0   0     3
# 131  1.52614  13.70  0.00  1.36  71.24  0.19  13.44   0   1     0
# 207  1.51831  14.39  0.00  1.82  72.86  1.41   6.47   1   0     4
# 179  1.51852  14.09  2.19  1.66  72.67  0.00   9.32   0   0     3
# 170  1.52369  13.44  0.00  1.58  72.22  0.32  12.24   0   0     2
# 76   1.51645  13.44  3.61  1.54  72.39  0.66   8.03   0   0     0
# 65   1.52099  13.69  3.59  1.12  71.96  0.09   9.40   0   0     0

# %% [markdown]
# ##Feature Engineering

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
data = df[['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe']]

# %%
data.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe'], dtype='object')

# %%
target = df[['Type']]

# %%
target.columns
# Out:
# Index(['Type'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.25, random_state=0, stratify = Type)

# %%
X_train.shape
# Out:
# (160, 9)

# %%
y_train = y_train.values.ravel()
y_train.shape
# Out:
# (160,)

# %%
X_test.shape
# Out:
# (54, 9)

# %%
y_test = y_test.values.ravel()
y_test.shape
# Out:
# (54,)

# %% [markdown]
# ## Standardizing Data

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# ## Why do we need to scale our data?
# * If a feature’s variance is orders of magnitude more than the variance of other features, that particular feature might dominate other features in the dataset and make the estimator unable to learn from other features correctly, i.e. our learner might give more importance to features with high variance, which is not something we want happening in our model.
#
# The following are a few different types of Scalers:

# %% [markdown]
# **MinMax Scaler:**
#
# Scales values to a range between 0 and 1 if no negative values, and -1 to 1 if there are negative values present.
#
# $$\frac{X - X_{min}}{X_{max} - X_{min}}$$
#
# where,
#
#  $$X\space is\space a\space feature\space value.$$
#  $$X_{min} \space and \space X_{max} \space are \space corresponding \space feature's \space min \space and \space max \space values. $$
#
#
# **Standard Scaler:**
#
# $$\frac{X - mean}{\sigma}$$
# where,
# $$\sigma = standard \space deviation $$
#
# **Robust Scaler:**
#
# Uses statistics that are robust to outliers
#
# $$\frac{X - median}{IQR}$$
#
# where,
#
# $$ IQR = Inter\space Quartile\space Range = Q_3 - Q_1 $$

# %% [markdown]
# Sklearn library provides functions for different scalers by which we can easily scale our data.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform (X_train)

# %%
X_test_scaled = scaler.transform (X_test)

# %% [markdown]
# We can see that after Min-Max Scaling all the values are in the range [0,1]

# %%
print("per-feature minimum before scaling:\n {}".format(X_train.min(axis=0)))
print("per-feature maximum before scaling:\n {}".format(X_train.max(axis=0)))
# Out:
# per-feature minimum before scaling:
#  RI     1.51115
# Na    10.73000
# Mg     0.00000
# Al     0.29000
# Si    69.81000
# K      0.00000
# Ca     5.43000
# Ba     0.00000
# Fe     0.00000
# dtype: float64
# per-feature maximum before scaling:
#  RI     1.53393
# Na    17.38000
# Mg     4.49000
# Al     3.04000
# Si    75.41000
# K      6.21000
# Ca    16.19000
# Ba     1.00000
# Fe     1.00000
# dtype: float64

# %%
print("per-feature minimum after scaling:\n {}".format(X_train_scaled.min(axis=0)))
print("per-feature maximum after scaling:\n {}".format(X_train_scaled.max(axis=0)))
# Out:
# per-feature minimum after scaling:
#  [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# per-feature maximum after scaling:
#  [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Effect of using MinMax Scaler:

# %% [markdown]
# ### Accuracy without scaling

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

print("Test set accuracy: {:.2f}".format(knn.score(X_test, y_test)))
# Out:
# Test set accuracy: 0.83

# %% [markdown]
# ### We can see that accuracy improves if we train on scaled data.

# %%
knn.fit(X_train_scaled, y_train)

# scoring on the scaled test set
print("Scaled test set accuracy: {:.2f}".format(knn.score(X_test_scaled, y_test)))
# Out:
# Scaled test set accuracy: 0.78

# %% [markdown]
# ### Effect using Standard Scaler:
# We can see that accuracy has improved compared to the non-scaled version, but we can infer that for this problem, Standard Scaler performs worse than MinMaxScaler.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# learning an SVM on the scaled training data
knn.fit(X_train_scaled, y_train)

# scoring on the scaled test set
print("KNN test accuracy: {:.2f}".format(knn.score(X_test_scaled, y_test)))
# Out:
# KNN test accuracy: 0.81

# %% [markdown]
# .
